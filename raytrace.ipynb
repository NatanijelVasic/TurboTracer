# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import threading

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
print('Load start')
framebuffer_cpp = np.loadtxt('/Users/natanijelvasic/Desktop/TurboTracer/frames/output.txt')
print('Load end')
framebuffer_cpp = framebuffer_cpp.reshape(600, 1000, 3)
print(framebuffer_cpp.shape)

# blur = 0.1*gaussian_filter(framebuffer_cpp, sigma=4)
# blurr = 0.5*gaussian_filter(framebuffer_cpp, sigma=60)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

fig, ax = plt.subplots(figsize=(32, 20))
# ax.imshow(framebuffer_cpp + blur + blurr, vmin=0, vmax=ITER/7, cmap='magma') # ITER/6
ax.imshow(3.2*(framebuffer_cpp))
# Out:
# Load start
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Load end
# (600, 1000, 3)

# %%
import imageio
imageio.plugins.freeimage.download()
img = imageio.imread('/Users/natanijelvasic/Desktop/TurboTracer/pano/pano.hdr', format='HDR-FI')
print(img.shape)
plt.imshow(img)
print(np.amin(img))
print(np.amax(img))

np.savetxt('/Users/natanijelvasic/Desktop/raytrace/pano/pano_r.txt', img[:, :, 0])
np.savetxt('/Users/natanijelvasic/Desktop/raytrace/pano/pano_g.txt', img[:, :, 1])
np.savetxt('/Users/natanijelvasic/Desktop/raytrace/pano/pano_b.txt', img[:, :, 2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (512, 1024, 3)
# 0.0
# 6496.0

# %%
foo = np.loadtxt('/Users/natanijelvasic/Desktop/TurboTracer/pano/pano_g.txt')
print(np.amax(foo))
plt.imshow(foo, vmax = 1)
# Out:
# 90112.0
